# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
frontal_bAcc = [65.5714, 52.8571, 51.8571, 59.4286, 48.2857, 50.2857]
temporal_bAcc = [62.0000, 57.8571, 62.4286, 56.8571, 57.8571, 60.4286]

plt.bar(['Frontal', 'Temporal'], [np.mean(frontal_bAcc), np.mean(temporal_bAcc)], yerr=[np.std(frontal_bAcc), np.std(temporal_bAcc)])
plt.ylabel('Balanced Accuracy (%)')
# Out:
# Text(0, 0.5, 'Balanced Accuracy (%)')
