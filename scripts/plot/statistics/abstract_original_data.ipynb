# %%
import numpy as np

# check current data whether if it is normalized
data_path = '/Users/shanxiafeng/Documents/Project/Research/fnirs-prognosis/code/fnirs-treatment-response-prediction/allData/prognosis/pre_treatment_hamd_reduction_50/data.npy'
data = np.load(data_path)
print(data.shape)
# Out:
# (65, 52, 2502)

# %%
mean_data = np.mean(data,axis=(0,1))
import matplotlib.pyplot as plt

plt.plot(mean_data)
plt.xlabel('Time')
plt.ylabel('Mean Data')
plt.title('Plot of Mean Data')
plt.show()

print('It shows the data of mine is normalizedm which is not suitable for statiscs analysis')
# Out:
# It shows the data of mine is normalizedm which is not suitable for statiscs analysis

# %%
original_pre_data_path = '/Users/shanxiafeng/Documents/Project/Research/fnirs-prognosis/code/fnirs-treatment-response-prediction/allData/prognosis/base_data.npy'
original_pre_data = np.load(original_pre_data_path)
print(original_pre_data.shape)
mean_original_pre_data = np.mean(original_pre_data, axis=(0, 2))
plt.plot(mean_original_pre_data)
plt.xlabel('Time')
plt.ylabel('Mean Data')
plt.title('Plot of Mean Original Data')
plt.show()
# Out:
# (65, 1251, 52, 2)

# %%
original_pre_post_data_path = '/Users/shanxiafeng/Documents/Project/Research/fnirs-prognosis/code/fnirs-treatment-response-prediction/allData/prognosis/base_t8_data.npy'
original_pre_post_data = np.load(original_pre_post_data_path)
print(original_pre_post_data.shape)
# Out:
# (46, 1251, 52, 2, 2)

# %%
import numpy as np

file_path = '/Users/shanxiafeng/Documents/Project/Research/fnirs-prognosis/code/fnirs-treatment-response-prediction/allData/prognosis/DMFC/pre_post_treatment_hamd_reduction_50/data.npy'
data = np.load(file_path)
print(data.shape)
# Out:
# (46, 52, 52, 3, 2)

# %%
import os

folder_path = 'gnn_transformer/pre_treatment_hamd_reduction_50'

for filename in os.listdir(folder_path):
    print(filename)
