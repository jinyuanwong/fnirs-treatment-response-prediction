# %%
import numpy as np
import time
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import LeaveOneOut
import os

from sklearn.metrics import confusion_matrix, roc_auc_score, f1_score
from sklearn.preprocessing import label_binarize



from scipy.stats import mannwhitneyu    
from xgboost import XGBClassifier
import random
from sklearn.model_selection import KFold

# sig_data = DATA.reshape(DATA.shape[0], -1)
def train_model_using_kfold(data, label, model, n_splits=10):
    kf = KFold(n_splits=n_splits, shuffle=True)
    result = []

    # Loop over each train/test split
    for train_index, test_index in kf.split(data):
        # Split the data into training and testing sets
        X_train, X_test = data[train_index], data[test_index]
        y_train, y_test = label[train_index], label[test_index]

        # Train the classifier
        model.fit(X_train, y_train)

        # Predict the label for the test set
        y_pred = model.predict(X_test)

        # Append the accuracy to the list
        result.append([y_pred, y_test])

    return np.array(result)


def train_model_using_loocv(data, label, model):
    loo = LeaveOneOut()
    result = []

    # Loop over each train/test split
    for train_index, test_index in loo.split(data):
        # Split the data into training and testing sets
        X_train, X_test = data[train_index], data[test_index]
        y_train, y_test = label[train_index], label[test_index]

        # Train the classifier
        model.fit(X_train, y_train)

        # Predict the label for the test set
        y_pred = model.predict(X_test)

        # Append the accuracy to the list
        result.append([y_pred, y_test])

    return np.array(result), model

stats_method = 'mannwhitneyu' # 'ranksums' or 'mannwhitneyu'
def zero_diagnonal(arr):
    # Loop over the first and last dimension
    for i in range(arr.shape[0]):  # Loop over subjects
        for j in range(arr.shape[-1]):  # Loop over views
            np.fill_diagonal(arr[i, :, :, j], 0)
    return arr


def return_significant_FCvalue(adj, labels):
    adj = zero_diagnonal(adj)
    hc_adj = adj[np.where(labels==1)]
    md_adj = adj[np.where(labels==0)]
    count = 0

    num_view = adj.shape[-1]
    p_view = np.zeros((52,52,num_view))
    effect_size = np.zeros((52,52,num_view))
    stats = np.zeros((52,52,num_view))
    for view in range(num_view):
        for seed in range(52):
            for target in range(52):
                hc_val = hc_adj[:, seed, target, view]
                md_val = md_adj[:, seed, target, view]
                if stats_method == 'mannwhitneyu':
                    stat, p1 = mannwhitneyu(hc_val,md_val)

                else:
                    raise ValueError('stats_method should be mannwhitneyu or ranksums')
                p_view[seed, target, view] = p1
                stats[seed, target, view] = stat
    
    adj = adj.reshape(adj.shape[0], -1)
    p_view = p_view.reshape(-1)
    return adj[:, p_view<0.05]



# caculating_10_important_features
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import kurtosis
from scipy.stats import skew


def get_activity_start_time(data, index_start):
    gradient = np.gradient(data)
    max_gradient = np.argmax(gradient[0:int(index_start*1.2)])  # 0:index_start*4 # current index_start = 400,
    if max_gradient <= index_start:
        max_gradient = index_start
    return max_gradient


"""
Calulate the left slope based on the data sample time from activity_start_time and  activity_start_time + task_duration//2
"""


def get_left_slope(data, activity_start, task_duration):
    activity_start = int(activity_start)
    data = data[activity_start: activity_start+task_duration//2]
    slope, _ = np.polyfit(np.arange(data.shape[0]), data, 1)
    return slope


"""
Calulate the right slope based on the data sample time from activity_start_time + task_duration//2 and activity_start_time + task_duration  
"""


def get_right_slope(data, activity_start, task_duration):
    activity_start = int(activity_start)
    data = data[activity_start+task_duration//2: activity_start+task_duration]
    slope, _ = np.polyfit(np.arange(data.shape[0]), data, 1)
    return slope


"""
For calculating FWHM
"""


def find_nearest(array, value):
    idx = (np.abs(array - value)).argmin()
    return idx


def get_FWHM(y_values, activity_start, task_duration):
    # make sure the peak value is situated in the task duration period
    task = y_values[activity_start:activity_start+task_duration]
    max_task = np.max(task)  # Find the maximum y value
    half_max_y = max_task / 2.0
    max_index_task = np.argmax(task)
    # if max_index_task is in the first two values, set left_index to 0
    if max_index_task <= 1:
        left_index = 0
    else:
        left_index = find_nearest(y_values[:max_index_task], half_max_y)
    # if max_index_task is in the last two values, set right_index to the last value
    if max_index_task >= activity_start+task_duration-1:
        right_index = task_duration-1
    else:
        right_index = find_nearest(
            y_values[max_index_task:], half_max_y) + max_index_task

    return right_index - left_index


"""Get all 10 features"""


def get_10_features(hbo, index_start, task_duration):
    feature_shape = hbo.shape[:2]
    # Feature 1 mean
    mean = np.mean(hbo, axis=2)  # feature shape is (subject, channel)

    # Feature 2 variance
    variance = np.std(hbo, axis=2)  # feature shape is (subject, channel)

    # Feature 3 activity_start_time
    activity_start_time = np.empty_like(mean)
    for sub in range(feature_shape[0]):
        for ch in range(feature_shape[1]):
            activity_start_time[sub, ch] = get_activity_start_time(
                hbo[sub, ch], index_start=index_start)

    # # Feature 4 left_slope
    left_slope = np.empty_like(mean)
    for sub in range(feature_shape[0]):
        for ch in range(feature_shape[1]):
            left_slope[sub, ch] = get_left_slope(
                hbo[sub, ch], activity_start=activity_start_time[sub, ch], task_duration=task_duration)
    # # Feature 5  right_slope
    right_slope = np.empty_like(mean)
    for sub in range(feature_shape[0]):
        for ch in range(feature_shape[1]):
            right_slope[sub, ch] = get_right_slope(
                hbo[sub, ch], activity_start=activity_start_time[sub, ch], task_duration=task_duration)

    # # Feature 6 kurtosis
    kurt = np.empty_like(mean)
    for sub in range(feature_shape[0]):
        for ch in range(feature_shape[1]):
            kurt[sub, ch] = kurtosis(hbo[sub, ch])
    # There might be some nan in kurtosis calucaltion because of all 0-value array
    kurt = np.nan_to_num(kurt)

    # # Feature 7 skewness
    skewness = np.empty_like(mean)
    for sub in range(feature_shape[0]):
        for ch in range(feature_shape[1]):
            skewness[sub, ch] = skew(hbo[sub, ch])
    # There might be some nan in skewness calucaltion because of all 0-value array
    skewness = np.nan_to_num(skewness)

    # # Feature 8 area under the curve AUC Based on the sample time from activity_start_time + task_duration
    AUC = np.empty_like(mean)
    for sub in range(feature_shape[0]):
        for ch in range(feature_shape[1]):
            activity_start = int(activity_start_time[sub, ch])
            AUC[sub, ch] = np.sum(
                hbo[sub, ch][activity_start:activity_start+task_duration])
    # for sub in range(10):
    #     plt.plot(AUC[sub])

    # # Feature 9 full width half maximum (FWHM)
    # FWHM
    FWHM = np.empty_like(mean)
    for sub in range(feature_shape[0]):
        for ch in range(feature_shape[1]):
            activity_start = int(activity_start_time[sub, ch])
            FWHM[sub, ch] = get_FWHM(
                hbo[sub, ch], activity_start, task_duration)
    # for sub in range(10):
    #     plt.plot(FWHM[sub])

    # # Feature 10 peak
    peak = np.max(hbo, axis=2)

    features = np.concatenate((mean, variance, activity_start_time,
                              left_slope, right_slope, kurt, skewness, AUC, FWHM, peak), axis=1)

    return features

def get_significant_feature(data, labels):
    hc_adj = data[np.where(labels==1)]
    md_adj = data[np.where(labels==0)]
    count = 0

    p_view = np.zeros((hc_adj.shape[1:]))
    for view in range(p_view.shape[-1]):
        hc_val = hc_adj[:, view]
        mdd_val = md_adj[:, view]
        _, p1 = mannwhitneyu(hc_val,mdd_val)
        p_view[view] = p1

    data = data.reshape(data.shape[0], -1)
    p_view = p_view.reshape(-1)
    data = data[:, p_view<0.05]

    return data 


def get_metrics(y_true, y_pred):
    # tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()

    # 明确指定labels参数
    cm = confusion_matrix(y_true, y_pred, labels=[0, 1])

    # 现在cm是一个2x2矩阵，即使数据只包含一个类别
    tn, fp, fn, tp = cm.ravel()

    accuracy = (tp + tn) / (tp + tn + fp + fn)
    sensitivity = tp / (tp + fn)
    specificity = tn / (tn + fp)
    f1 = f1_score(y_true, y_pred)

    return accuracy, sensitivity, specificity, f1






def print_md_table(model_name, set, metrics):
    print()
    print('| Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |')
    print('|------------|----------|----------|-------------|-------------|----------|')
    print(f'| {model_name} | {set} |', end = '')
    for i in range(4):
        print(f" {metrics[i]:.4f} |", end = '')
    print()

# %%
output_fold = '/Users/shanxiafeng/Documents/Project/Research/fnirs-prognosis/code/fnirs-treatment-response-prediction/results/ML_results'
if not os.path.exists(output_fold):
    os.makedirs(output_fold)




res = {}

# 初始化模型，同时设置随机种子
models = {
    # "Logistic Regression": LogisticRegression(max_iter=150),
    "Decision Tree": DecisionTreeClassifier(),
    # "Random Forest": RandomForestClassifier(),
    # "SVM": SVC(),
}
for name, model in models.items():
    # run multiple time, using different time stamp as random seed
    for num_time in range(1):
        print(f'current training {name}, num_time: {num_time}')

        # 使用当前时间戳作为随机种子
        current_time_seed = 1706166341

        # build model
        model.random_state = current_time_seed

        hb_result = {}
        HB_TYPE_accuraies = {}
        HB_TYPE_y_pred_and_y_test = {}
        for HB_TYPE in ['HbO', 'HbR', 'HbT']:
            HB_TYPE_accuraies[HB_TYPE] = []
            HB_TYPE_y_pred_and_y_test[HB_TYPE] = []

            # read data
            fold = '/Users/shanxiafeng/Documents/Project/Research/fnirs-prognosis/code/fnirs-treatment-response-prediction/allData/diagnosis'

            hb = np.load(fold + '/fc_data.npy')
            hb = np.nan_to_num(hb)
            label = np.load(fold + '/label.npy')

            if HB_TYPE == 'HbO':
                hb = hb[..., 0]
            elif HB_TYPE == 'HbR':
                hb = hb[..., 1]
            else:
                hb = hb[..., 2]
            hb_2d = np.reshape(hb, (hb.shape[0], -1))

            # Apply LOOCV to train the model
            # Initialize LeaveOneOut
            loo = LeaveOneOut()

            # 存储每个模型的准确率
            accuracies = {}

            # Loop over each train/test split
            for train_index, test_index in loo.split(hb_2d):
                # Split the data into training and testing sets
                X_train, X_test = hb_2d[train_index], hb_2d[test_index]
                y_train, y_test = label[train_index], label[test_index]

                # Train the classifier
                model.fit(X_train, y_train)

                # Predict the label for the test set
                y_pred = model.predict(X_test)

                # Calculate the accuracy for the current fold
                accuracy = accuracy_score(y_test, y_pred)

                # Append the accuracy to the list
                HB_TYPE_accuraies[HB_TYPE].append(accuracy)

                HB_TYPE_y_pred_and_y_test[HB_TYPE].append([y_pred, y_test])
            accuracies[HB_TYPE] = 1
            accuracies[HB_TYPE] = np.mean(HB_TYPE_accuraies[HB_TYPE])

        save_result = {}
        save_result['accuracies'] = accuracies
        save_result['model_accuraies'] = HB_TYPE_accuraies
        save_result['current_time_seed'] = current_time_seed
        save_result['num_time'] = num_time
        save_result['HB_TYPE_y_pred_and_y_test'] = HB_TYPE_y_pred_and_y_test

        res[f'{num_time}'] = save_result
    # np.save(output_fold + f'/{name}_result_validate.npy', res)
# Out:
# current training Decision Tree, num_time: 0

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, roc_auc_score, f1_score


for hb_type in ['HbO', 'HbR', 'HbT']:
    res_true_pred = np.array(save_result['HB_TYPE_y_pred_and_y_test'][hb_type])

    y_true = res_true_pred[:, 1]
    y_pred = res_true_pred[:, 0]

    res_metrics = get_metrics(y_true, y_pred)
    print_md_table('Decision Tree', 'test' + hb_type, res_metrics)
# Out:
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | testHbO | 0.5929 | 0.6000 | 0.5857 | 0.5957 |
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | testHbR | 0.4571 | 0.3714 | 0.5429 | 0.4062 |
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | testHbT | 0.2643 | 0.2571 | 0.2714 | 0.2590 |

# %%
# read data 
RS_FC = np.load('/Users/shanxiafeng/Documents/Project/Research/fnirs-prognosis/code/fnirs-treatment-response-prediction/allData/diagnosis/fc_data.npy')
LABEL = np.load('/Users/shanxiafeng/Documents/Project/Research/fnirs-prognosis/code/fnirs-treatment-response-prediction/allData/diagnosis/label.npy')

HB = np.load('/Users/shanxiafeng/Documents/Project/Research/fnirs-prognosis/code/fnirs-treatment-response-prediction/allData/diagnosis/hb_data.npy')



from scipy.stats import zscore
demographic_path = '/Users/shanxiafeng/Documents/Project/Research/fnirs-prognosis/code/fnirs-treatment-response-prediction/allData/diagnosis/demographic_data.npy'
demo_data = np.load(demographic_path)
demo_data_normalized = zscore(demo_data, axis=0)
deleted_demo_data_normalized = np.delete(demo_data_normalized, 6, axis=1)




hbo_10_features = get_10_features(HB[..., 0], 100, 600)
hbr_10_features = get_10_features(HB[..., 1], 100, 600)
hbt_10_features = get_10_features(HB[..., 2], 100, 600)
# get the significant data 
significant_FC = return_significant_FCvalue(RS_FC, LABEL)
sig_hbo_feature = get_significant_feature(hbo_10_features, LABEL)
sig_hbr_feature = get_significant_feature(hbr_10_features, LABEL)
sig_hbt_feature = get_significant_feature(hbt_10_features, LABEL)

sig_hb = np.concatenate((sig_hbo_feature, sig_hbr_feature, sig_hbt_feature), axis=1)


sig_data = np.concatenate((significant_FC, sig_hb), axis=1)
sig_demographic_fc = np.concatenate((demo_data_normalized, significant_FC), axis=1)
# using XGBoost to train the model

# show the result

# %%
sig_demographic_fc = np.concatenate((deleted_demo_data_normalized, significant_FC), axis=1)

# %%
sig_demographic_fc.shape
# Out:
# (140, 219)

# %%
while True:
    learning_rate = random.uniform(0.1, 0.6)
    n_estimators = np.random.choice([1,5,50,100,200,500,1000])
    model = XGBClassifier(
        learning_rate=learning_rate,
        max_depth=20,
        reg_alpha=10,
        reg_lambda=15,
        n_estimators= n_estimators,
    )
# 存储每个模型的准确率
    result,model = train_model_using_loocv(significant_FC, LABEL, model)
    res_metrics = get_metrics(result[:, 1], result[:, 0])
    
    # result = train_model_using_kfold(deleted_demo_data_normalized, LABEL, model)
    # res_metrics = kfold_get_metrics(result)
    print(f'learning_rate: {learning_rate}, n_estimators: {n_estimators}')
    print_md_table('Decision Tree', 'test', res_metrics)
    # break
# Out:
# learning_rate: 0.3379111643491901, n_estimators: 100
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4643 | 0.4286 | 0.5000 | 0.4444 |
# learning_rate: 0.10199916128197564, n_estimators: 5
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4000 | 0.3429 | 0.4571 | 0.3636 |
# learning_rate: 0.12457909835338773, n_estimators: 5
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4000 | 0.3429 | 0.4571 | 0.3636 |
# learning_rate: 0.3686885724371425, n_estimators: 50
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4786 | 0.4286 | 0.5286 | 0.4511 |
# learning_rate: 0.3624221107397977, n_estimators: 1
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.2500 | 0.1857 | 0.3143 | 0.1985 |
# learning_rate: 0.3719537170627062, n_estimators: 5
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4786 | 0.4429 | 0.5143 | 0.4593 |
# learning_rate: 0.4935520640094774, n_estimators: 1000
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4857 | 0.4571 | 0.5143 | 0.4706 |
# learning_rate: 0.5369997828258092, n_estimators: 100
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4786 | 0.4571 | 0.5000 | 0.4672 |
# learning_rate: 0.5289274171823177, n_estimators: 1000
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4857 | 0.4714 | 0.5000 | 0.4783 |
# learning_rate: 0.36370112120139486, n_estimators: 500
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4857 | 0.4286 | 0.5429 | 0.4545 |
# learning_rate: 0.42084528499223317, n_estimators: 1
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.2500 | 0.1857 | 0.3143 | 0.1985 |
# learning_rate: 0.5392590809196383, n_estimators: 50
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4786 | 0.4571 | 0.5000 | 0.4672 |
# learning_rate: 0.4643650991217929, n_estimators: 50
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4786 | 0.4571 | 0.5000 | 0.4672 |
# learning_rate: 0.5412628756088819, n_estimators: 50
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4714 | 0.4429 | 0.5000 | 0.4559 |
# learning_rate: 0.1967455020846636, n_estimators: 1000
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4857 | 0.4571 | 0.5143 | 0.4706 |
# learning_rate: 0.10763181208288095, n_estimators: 50
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4929 | 0.4571 | 0.5286 | 0.4741 |
# learning_rate: 0.24632209015546694, n_estimators: 500
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4786 | 0.4429 | 0.5143 | 0.4593 |
# learning_rate: 0.44828437665502197, n_estimators: 5
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4786 | 0.4571 | 0.5000 | 0.4672 |
# learning_rate: 0.2629094269445039, n_estimators: 500
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4714 | 0.4429 | 0.5000 | 0.4559 |
# learning_rate: 0.39936037380830125, n_estimators: 50
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4643 | 0.4286 | 0.5000 | 0.4444 |
# learning_rate: 0.28623116351020816, n_estimators: 100
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4643 | 0.4286 | 0.5000 | 0.4444 |
# learning_rate: 0.13689049293864955, n_estimators: 50
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4786 | 0.4429 | 0.5143 | 0.4593 |
# learning_rate: 0.20569419261650776, n_estimators: 5
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4214 | 0.3571 | 0.4857 | 0.3817 |
# learning_rate: 0.183397818128769, n_estimators: 50
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.5000 | 0.4714 | 0.5286 | 0.4853 |
# learning_rate: 0.2058503234187248, n_estimators: 1
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.2500 | 0.1857 | 0.3143 | 0.1985 |
# learning_rate: 0.2807945506287798, n_estimators: 1
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.2500 | 0.1857 | 0.3143 | 0.1985 |
# learning_rate: 0.5747576961719467, n_estimators: 1000
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4929 | 0.4714 | 0.5143 | 0.4818 |
# learning_rate: 0.13335262685061808, n_estimators: 100
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4857 | 0.4571 | 0.5143 | 0.4706 |
# learning_rate: 0.14387908105428285, n_estimators: 200
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4857 | 0.4571 | 0.5143 | 0.4706 |
# learning_rate: 0.5301887035920418, n_estimators: 5
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4857 | 0.4714 | 0.5000 | 0.4783 |
# learning_rate: 0.5700693648764342, n_estimators: 1000
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4929 | 0.4714 | 0.5143 | 0.4818 |
# learning_rate: 0.2433143415867817, n_estimators: 50
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4786 | 0.4429 | 0.5143 | 0.4593 |
# learning_rate: 0.3397935505543431, n_estimators: 200
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4643 | 0.4286 | 0.5000 | 0.4444 |
# learning_rate: 0.3184022236523474, n_estimators: 1000
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4714 | 0.4143 | 0.5286 | 0.4394 |
# learning_rate: 0.2774705875097483, n_estimators: 1
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.2500 | 0.1857 | 0.3143 | 0.1985 |
# learning_rate: 0.5462565441849991, n_estimators: 50
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4714 | 0.4429 | 0.5000 | 0.4559 |
# learning_rate: 0.12662115012122102, n_estimators: 5
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4000 | 0.3429 | 0.4571 | 0.3636 |
# learning_rate: 0.32064337375715213, n_estimators: 1000
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4643 | 0.4143 | 0.5143 | 0.4361 |
# learning_rate: 0.3139345502829487, n_estimators: 100
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4786 | 0.4286 | 0.5286 | 0.4511 |
# learning_rate: 0.5930720990318892, n_estimators: 1
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.2500 | 0.1857 | 0.3143 | 0.1985 |
# learning_rate: 0.1331675326112419, n_estimators: 50
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4714 | 0.4429 | 0.5000 | 0.4559 |
# learning_rate: 0.4366557462945925, n_estimators: 1
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.2500 | 0.1857 | 0.3143 | 0.1985 |
# learning_rate: 0.4353164287496406, n_estimators: 1
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.2500 | 0.1857 | 0.3143 | 0.1985 |
# learning_rate: 0.22563514567013895, n_estimators: 500
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4786 | 0.4571 | 0.5000 | 0.4672 |
# learning_rate: 0.3717556693541284, n_estimators: 100
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4714 | 0.4286 | 0.5143 | 0.4478 |
# learning_rate: 0.2956202553499724, n_estimators: 1000
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4714 | 0.4429 | 0.5000 | 0.4559 |
# learning_rate: 0.42963770844478355, n_estimators: 5
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4857 | 0.4571 | 0.5143 | 0.4706 |
# learning_rate: 0.4027178054353685, n_estimators: 200
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4500 | 0.4000 | 0.5000 | 0.4211 |
# learning_rate: 0.4559810241510387, n_estimators: 50
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4714 | 0.4429 | 0.5000 | 0.4559 |
# learning_rate: 0.15718824848686155, n_estimators: 50
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4786 | 0.4571 | 0.5000 | 0.4672 |
# learning_rate: 0.26816897876271284, n_estimators: 1
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.2500 | 0.1857 | 0.3143 | 0.1985 |
# learning_rate: 0.18216143299899626, n_estimators: 1000
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.5000 | 0.4714 | 0.5286 | 0.4853 |
# learning_rate: 0.3448159081714385, n_estimators: 1
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.2500 | 0.1857 | 0.3143 | 0.1985 |
# learning_rate: 0.2726560491226385, n_estimators: 50
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4786 | 0.4429 | 0.5143 | 0.4593 |
# learning_rate: 0.20218334430810772, n_estimators: 200
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4857 | 0.4571 | 0.5143 | 0.4706 |
# learning_rate: 0.16751894872474235, n_estimators: 50
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4929 | 0.4571 | 0.5286 | 0.4741 |
# learning_rate: 0.2516186253092856, n_estimators: 50
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4786 | 0.4429 | 0.5143 | 0.4593 |
# learning_rate: 0.10081756513546727, n_estimators: 50
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.5071 | 0.4714 | 0.5429 | 0.4889 |
# learning_rate: 0.3429665880779854, n_estimators: 100
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4714 | 0.4429 | 0.5000 | 0.4559 |
# learning_rate: 0.39860525229431587, n_estimators: 50
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4643 | 0.4286 | 0.5000 | 0.4444 |
# learning_rate: 0.13193512880641642, n_estimators: 100
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4786 | 0.4429 | 0.5143 | 0.4593 |
# learning_rate: 0.2570983281256066, n_estimators: 200
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4714 | 0.4429 | 0.5000 | 0.4559 |
# learning_rate: 0.5738999260201836, n_estimators: 5
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4929 | 0.4714 | 0.5143 | 0.4818 |
# learning_rate: 0.19914841558436577, n_estimators: 1
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.2500 | 0.1857 | 0.3143 | 0.1985 |
# learning_rate: 0.5736204976932364, n_estimators: 1
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.2500 | 0.1857 | 0.3143 | 0.1985 |
# learning_rate: 0.5192954722313373, n_estimators: 500
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4786 | 0.4571 | 0.5000 | 0.4672 |
# learning_rate: 0.14076477647939192, n_estimators: 100
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4929 | 0.4714 | 0.5143 | 0.4818 |
# learning_rate: 0.4526846522568465, n_estimators: 1000
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4786 | 0.4571 | 0.5000 | 0.4672 |
# learning_rate: 0.5322021337084818, n_estimators: 1
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.2500 | 0.1857 | 0.3143 | 0.1985 |
# learning_rate: 0.25750417699418715, n_estimators: 100
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4786 | 0.4571 | 0.5000 | 0.4672 |
# learning_rate: 0.40844460870447297, n_estimators: 100
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4500 | 0.4000 | 0.5000 | 0.4211 |
# learning_rate: 0.3939450628253086, n_estimators: 200
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4571 | 0.4143 | 0.5000 | 0.4328 |
# learning_rate: 0.47995274070658545, n_estimators: 5
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4714 | 0.4429 | 0.5000 | 0.4559 |
# learning_rate: 0.5523333755777021, n_estimators: 5
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4714 | 0.4429 | 0.5000 | 0.4559 |
# learning_rate: 0.14447363288048645, n_estimators: 5
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4071 | 0.3429 | 0.4714 | 0.3664 |
# learning_rate: 0.22586284100639023, n_estimators: 100
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4786 | 0.4571 | 0.5000 | 0.4672 |
# learning_rate: 0.23633331839002317, n_estimators: 500
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4643 | 0.4286 | 0.5000 | 0.4444 |
# learning_rate: 0.3630065694075726, n_estimators: 100
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4857 | 0.4286 | 0.5429 | 0.4545 |
# learning_rate: 0.1259744826354123, n_estimators: 100
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4786 | 0.4286 | 0.5286 | 0.4511 |
# learning_rate: 0.4465855019652146, n_estimators: 50
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4857 | 0.4571 | 0.5143 | 0.4706 |
# learning_rate: 0.4897121702367856, n_estimators: 50
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4786 | 0.4571 | 0.5000 | 0.4672 |
# learning_rate: 0.27452722798339935, n_estimators: 100
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4786 | 0.4429 | 0.5143 | 0.4593 |
# learning_rate: 0.2335437479185872, n_estimators: 200
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4786 | 0.4571 | 0.5000 | 0.4672 |
# learning_rate: 0.4024679176896713, n_estimators: 50
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4500 | 0.4000 | 0.5000 | 0.4211 |
# learning_rate: 0.2796385507447111, n_estimators: 5
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4357 | 0.3714 | 0.5000 | 0.3969 |
# learning_rate: 0.2537161284370878, n_estimators: 50
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4857 | 0.4571 | 0.5143 | 0.4706 |
# learning_rate: 0.45735395451547756, n_estimators: 1
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.2500 | 0.1857 | 0.3143 | 0.1985 |
# learning_rate: 0.40490546983528886, n_estimators: 1000
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4500 | 0.4000 | 0.5000 | 0.4211 |
# learning_rate: 0.5121627552167768, n_estimators: 200
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4786 | 0.4571 | 0.5000 | 0.4672 |
# learning_rate: 0.4822183248574061, n_estimators: 1000
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4714 | 0.4429 | 0.5000 | 0.4559 |
# learning_rate: 0.5732592756414223, n_estimators: 200
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4929 | 0.4714 | 0.5143 | 0.4818 |
# learning_rate: 0.13643183292869546, n_estimators: 5
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4071 | 0.3429 | 0.4714 | 0.3664 |
# learning_rate: 0.36297332196683996, n_estimators: 1000
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4857 | 0.4286 | 0.5429 | 0.4545 |
# learning_rate: 0.3820597381622661, n_estimators: 1
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.2500 | 0.1857 | 0.3143 | 0.1985 |
# learning_rate: 0.19392117691934738, n_estimators: 5
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4286 | 0.3714 | 0.4857 | 0.3939 |
# learning_rate: 0.4329191605174445, n_estimators: 1
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.2500 | 0.1857 | 0.3143 | 0.1985 |
# learning_rate: 0.5300262022510817, n_estimators: 5
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4857 | 0.4714 | 0.5000 | 0.4783 |
# learning_rate: 0.14812305857742222, n_estimators: 1000
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4857 | 0.4714 | 0.5000 | 0.4783 |
# learning_rate: 0.23673128509195776, n_estimators: 200
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4643 | 0.4286 | 0.5000 | 0.4444 |
# learning_rate: 0.41801921390709984, n_estimators: 50
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4786 | 0.4429 | 0.5143 | 0.4593 |
# learning_rate: 0.4505663109574439, n_estimators: 100
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4786 | 0.4571 | 0.5000 | 0.4672 |
# learning_rate: 0.10068461813045029, n_estimators: 50
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.5071 | 0.4714 | 0.5429 | 0.4889 |
# learning_rate: 0.5498808927043048, n_estimators: 500
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4714 | 0.4429 | 0.5000 | 0.4559 |
# learning_rate: 0.12742768366641458, n_estimators: 100
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4714 | 0.4286 | 0.5143 | 0.4478 |
# learning_rate: 0.5403866938124127, n_estimators: 1000
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4786 | 0.4571 | 0.5000 | 0.4672 |
# learning_rate: 0.39764494250544324, n_estimators: 200
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4643 | 0.4286 | 0.5000 | 0.4444 |
# learning_rate: 0.18490920501682204, n_estimators: 1
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.2500 | 0.1857 | 0.3143 | 0.1985 |
# learning_rate: 0.436597074174499, n_estimators: 1
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.2500 | 0.1857 | 0.3143 | 0.1985 |
# learning_rate: 0.46177989194766045, n_estimators: 500
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4714 | 0.4429 | 0.5000 | 0.4559 |
# learning_rate: 0.4669307331430278, n_estimators: 50
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4786 | 0.4571 | 0.5000 | 0.4672 |
# learning_rate: 0.3816155097875763, n_estimators: 1
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.2500 | 0.1857 | 0.3143 | 0.1985 |
# learning_rate: 0.31289069977166495, n_estimators: 500
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4786 | 0.4286 | 0.5286 | 0.4511 |
# learning_rate: 0.15572902453607232, n_estimators: 1000
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4786 | 0.4571 | 0.5000 | 0.4672 |
# learning_rate: 0.4229352132399711, n_estimators: 5
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4786 | 0.4429 | 0.5143 | 0.4593 |
# learning_rate: 0.2592640473954514, n_estimators: 5
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4357 | 0.4000 | 0.4714 | 0.4148 |
# learning_rate: 0.3154468309403533, n_estimators: 200
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4786 | 0.4286 | 0.5286 | 0.4511 |
# learning_rate: 0.38162034438910053, n_estimators: 5
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4714 | 0.4429 | 0.5000 | 0.4559 |
# learning_rate: 0.1743810417363809, n_estimators: 500
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.5071 | 0.4714 | 0.5429 | 0.4889 |
# learning_rate: 0.18589849364643282, n_estimators: 50
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4929 | 0.4714 | 0.5143 | 0.4818 |
# learning_rate: 0.32687231916953896, n_estimators: 1
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.2500 | 0.1857 | 0.3143 | 0.1985 |
# learning_rate: 0.16121884873294076, n_estimators: 200
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4857 | 0.4571 | 0.5143 | 0.4706 |
# learning_rate: 0.3846517627192666, n_estimators: 1000
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4643 | 0.4286 | 0.5000 | 0.4444 |
# learning_rate: 0.3208272856897185, n_estimators: 50
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4643 | 0.4143 | 0.5143 | 0.4361 |
# learning_rate: 0.5743633959758079, n_estimators: 1
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.2500 | 0.1857 | 0.3143 | 0.1985 |
# learning_rate: 0.31390396010428523, n_estimators: 1000
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4786 | 0.4286 | 0.5286 | 0.4511 |
# learning_rate: 0.1729752569108001, n_estimators: 200
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.5071 | 0.4714 | 0.5429 | 0.4889 |
# learning_rate: 0.21503190145950754, n_estimators: 1000
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.5000 | 0.4857 | 0.5143 | 0.4928 |
# learning_rate: 0.2557709073694169, n_estimators: 1
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.2500 | 0.1857 | 0.3143 | 0.1985 |
# learning_rate: 0.36369259205968496, n_estimators: 5
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4929 | 0.4429 | 0.5429 | 0.4662 |
# learning_rate: 0.27000160938162265, n_estimators: 200
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4786 | 0.4429 | 0.5143 | 0.4593 |
# learning_rate: 0.590565376676413, n_estimators: 5
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4786 | 0.4714 | 0.4857 | 0.4748 |
# learning_rate: 0.4068539387005633, n_estimators: 500
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4500 | 0.4000 | 0.5000 | 0.4211 |
# learning_rate: 0.34308655108361363, n_estimators: 1000
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4714 | 0.4429 | 0.5000 | 0.4559 |
# learning_rate: 0.19524266559964973, n_estimators: 1000
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4929 | 0.4714 | 0.5143 | 0.4818 |
# learning_rate: 0.5055834878234606, n_estimators: 200
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4786 | 0.4571 | 0.5000 | 0.4672 |
# learning_rate: 0.39904220452436157, n_estimators: 1
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.2500 | 0.1857 | 0.3143 | 0.1985 |
# learning_rate: 0.25511822062813827, n_estimators: 100
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4857 | 0.4571 | 0.5143 | 0.4706 |
# learning_rate: 0.16481329562604383, n_estimators: 200
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4857 | 0.4571 | 0.5143 | 0.4706 |
# learning_rate: 0.3698643337814478, n_estimators: 500
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4786 | 0.4286 | 0.5286 | 0.4511 |
# learning_rate: 0.5988553175857213, n_estimators: 500
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4786 | 0.4714 | 0.4857 | 0.4748 |
# learning_rate: 0.25024178707290656, n_estimators: 100
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4714 | 0.4286 | 0.5143 | 0.4478 |
# learning_rate: 0.5865368199396643, n_estimators: 1
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.2500 | 0.1857 | 0.3143 | 0.1985 |
# learning_rate: 0.2785319939793629, n_estimators: 100
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4714 | 0.4286 | 0.5143 | 0.4478 |
# learning_rate: 0.46935530041931595, n_estimators: 100
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4786 | 0.4571 | 0.5000 | 0.4672 |
# learning_rate: 0.5684543136354, n_estimators: 50
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4786 | 0.4571 | 0.5000 | 0.4672 |
# learning_rate: 0.5747678117310728, n_estimators: 5
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4929 | 0.4714 | 0.5143 | 0.4818 |
# learning_rate: 0.10398928884608225, n_estimators: 100
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4929 | 0.4429 | 0.5429 | 0.4662 |
# learning_rate: 0.4552750131196157, n_estimators: 5
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4714 | 0.4429 | 0.5000 | 0.4559 |
# learning_rate: 0.30473166539734886, n_estimators: 500
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4714 | 0.4286 | 0.5143 | 0.4478 |
# learning_rate: 0.26325536875394917, n_estimators: 1
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.2500 | 0.1857 | 0.3143 | 0.1985 |
# learning_rate: 0.44457206377924396, n_estimators: 1000
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4786 | 0.4571 | 0.5000 | 0.4672 |
# learning_rate: 0.5312594636100304, n_estimators: 100
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4857 | 0.4714 | 0.5000 | 0.4783 |
# learning_rate: 0.5679954203561494, n_estimators: 200
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4786 | 0.4571 | 0.5000 | 0.4672 |
# learning_rate: 0.37365704598909044, n_estimators: 100
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4714 | 0.4286 | 0.5143 | 0.4478 |
# learning_rate: 0.18983992899306248, n_estimators: 100
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4857 | 0.4714 | 0.5000 | 0.4783 |
# learning_rate: 0.11719850416657909, n_estimators: 500
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4929 | 0.4714 | 0.5143 | 0.4818 |
# learning_rate: 0.4711129063134275, n_estimators: 1
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.2500 | 0.1857 | 0.3143 | 0.1985 |
# learning_rate: 0.19552150690672263, n_estimators: 1
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.2500 | 0.1857 | 0.3143 | 0.1985 |
# learning_rate: 0.13200432208621007, n_estimators: 200
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4786 | 0.4429 | 0.5143 | 0.4593 |
# learning_rate: 0.177179688197911, n_estimators: 100
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.5000 | 0.4714 | 0.5286 | 0.4853 |
# learning_rate: 0.21110662977657965, n_estimators: 100
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4929 | 0.4714 | 0.5143 | 0.4818 |
# learning_rate: 0.14053452918371953, n_estimators: 200
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4929 | 0.4714 | 0.5143 | 0.4818 |
# learning_rate: 0.1492671712177788, n_estimators: 50
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4929 | 0.4714 | 0.5143 | 0.4818 |
# learning_rate: 0.2277976286343998, n_estimators: 500
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4786 | 0.4571 | 0.5000 | 0.4672 |
# learning_rate: 0.5422754631838868, n_estimators: 1
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.2500 | 0.1857 | 0.3143 | 0.1985 |
# learning_rate: 0.1512035671779365, n_estimators: 100
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4857 | 0.4714 | 0.5000 | 0.4783 |
# learning_rate: 0.47641820473605867, n_estimators: 100
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4714 | 0.4429 | 0.5000 | 0.4559 |
# learning_rate: 0.37819642430763145, n_estimators: 100
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4714 | 0.4286 | 0.5143 | 0.4478 |
# learning_rate: 0.4825567427107116, n_estimators: 200
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4714 | 0.4429 | 0.5000 | 0.4559 |
# learning_rate: 0.44347209936801446, n_estimators: 100
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4714 | 0.4571 | 0.4857 | 0.4638 |
# learning_rate: 0.49287468474614116, n_estimators: 100
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4857 | 0.4571 | 0.5143 | 0.4706 |
# learning_rate: 0.5610331654981436, n_estimators: 100
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4714 | 0.4429 | 0.5000 | 0.4559 |
# learning_rate: 0.17585481005093398, n_estimators: 200
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.5071 | 0.4714 | 0.5429 | 0.4889 |
# learning_rate: 0.20620879053212124, n_estimators: 200
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4929 | 0.4714 | 0.5143 | 0.4818 |
# learning_rate: 0.26656809523522573, n_estimators: 5
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4357 | 0.3714 | 0.5000 | 0.3969 |
# learning_rate: 0.5301073022909453, n_estimators: 50
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4857 | 0.4714 | 0.5000 | 0.4783 |
# learning_rate: 0.3538907534584178, n_estimators: 500
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4571 | 0.4143 | 0.5000 | 0.4328 |
# learning_rate: 0.49255400358968504, n_estimators: 1000
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4857 | 0.4571 | 0.5143 | 0.4706 |
# learning_rate: 0.585554355969825, n_estimators: 100
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4857 | 0.4857 | 0.4857 | 0.4857 |
# learning_rate: 0.46390962486859066, n_estimators: 200
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4786 | 0.4571 | 0.5000 | 0.4672 |
# learning_rate: 0.32682885518386406, n_estimators: 500
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4643 | 0.4143 | 0.5143 | 0.4361 |
# learning_rate: 0.17144277644684072, n_estimators: 100
#
# ...
# | Decision Tree | test | 0.2500 | 0.1857 | 0.3143 | 0.1985 |
# learning_rate: 0.33997329604525295, n_estimators: 500
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4643 | 0.4286 | 0.5000 | 0.4444 |
# learning_rate: 0.42710564496227366, n_estimators: 1
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.2500 | 0.1857 | 0.3143 | 0.1985 |
# learning_rate: 0.3272945152276342, n_estimators: 200
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4643 | 0.4143 | 0.5143 | 0.4361 |
# learning_rate: 0.3710084782446098, n_estimators: 500
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4714 | 0.4286 | 0.5143 | 0.4478 |
# learning_rate: 0.16666872061730167, n_estimators: 200
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4929 | 0.4571 | 0.5286 | 0.4741 |
# learning_rate: 0.36795782953895206, n_estimators: 50
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4857 | 0.4429 | 0.5286 | 0.4627 |
# learning_rate: 0.11329507009200931, n_estimators: 1000
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4929 | 0.4714 | 0.5143 | 0.4818 |
# learning_rate: 0.1922000822248023, n_estimators: 100
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4929 | 0.4714 | 0.5143 | 0.4818 |
# learning_rate: 0.4212061399478283, n_estimators: 50
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4786 | 0.4429 | 0.5143 | 0.4593 |
# learning_rate: 0.2210895884035959, n_estimators: 100
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4929 | 0.4714 | 0.5143 | 0.4818 |
# learning_rate: 0.5571908521219318, n_estimators: 100
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4643 | 0.4286 | 0.5000 | 0.4444 |
# learning_rate: 0.16934068903427238, n_estimators: 1
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.2500 | 0.1857 | 0.3143 | 0.1985 |
# learning_rate: 0.19148638311029367, n_estimators: 1000
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4929 | 0.4714 | 0.5143 | 0.4818 |
# learning_rate: 0.5198514835204608, n_estimators: 5
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4786 | 0.4571 | 0.5000 | 0.4672 |
# learning_rate: 0.5085198887438985, n_estimators: 5
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4786 | 0.4571 | 0.5000 | 0.4672 |
# learning_rate: 0.49074421641627697, n_estimators: 500
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4786 | 0.4571 | 0.5000 | 0.4672 |
# learning_rate: 0.25696088818584306, n_estimators: 5
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4214 | 0.3714 | 0.4714 | 0.3910 |
# learning_rate: 0.4435250662588166, n_estimators: 500
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4714 | 0.4571 | 0.4857 | 0.4638 |
# learning_rate: 0.20562416862946778, n_estimators: 500
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4929 | 0.4714 | 0.5143 | 0.4818 |
# learning_rate: 0.3962380830233705, n_estimators: 5
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4643 | 0.4286 | 0.5000 | 0.4444 |
# learning_rate: 0.579415940811915, n_estimators: 200
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4857 | 0.4857 | 0.4857 | 0.4857 |
# learning_rate: 0.19736782889729956, n_estimators: 100
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4857 | 0.4571 | 0.5143 | 0.4706 |
# learning_rate: 0.5533036960894171, n_estimators: 50
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4643 | 0.4286 | 0.5000 | 0.4444 |
# learning_rate: 0.12120242991120775, n_estimators: 5
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4071 | 0.3429 | 0.4714 | 0.3664 |
# learning_rate: 0.46099568630583754, n_estimators: 500
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4714 | 0.4429 | 0.5000 | 0.4559 |
# learning_rate: 0.32515956578147653, n_estimators: 5
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4714 | 0.4143 | 0.5286 | 0.4394 |
# learning_rate: 0.5852944451285848, n_estimators: 5
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4857 | 0.4857 | 0.4857 | 0.4857 |
# learning_rate: 0.3157294917447614, n_estimators: 200
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4786 | 0.4286 | 0.5286 | 0.4511 |
# learning_rate: 0.48355667177811323, n_estimators: 1000
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4714 | 0.4429 | 0.5000 | 0.4559 |
# learning_rate: 0.27769133235390187, n_estimators: 100
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4714 | 0.4286 | 0.5143 | 0.4478 |
# learning_rate: 0.3466365192117955, n_estimators: 5
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4786 | 0.4286 | 0.5286 | 0.4511 |
# learning_rate: 0.5234349106744606, n_estimators: 50
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4857 | 0.4714 | 0.5000 | 0.4783 |
# learning_rate: 0.43400583381684676, n_estimators: 100
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4857 | 0.4571 | 0.5143 | 0.4706 |
# learning_rate: 0.5419470413857433, n_estimators: 100
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4714 | 0.4429 | 0.5000 | 0.4559 |
# learning_rate: 0.24114133276296637, n_estimators: 1000
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4714 | 0.4286 | 0.5143 | 0.4478 |
# learning_rate: 0.351182655884132, n_estimators: 5
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4857 | 0.4429 | 0.5286 | 0.4627 |
# learning_rate: 0.3188452607683173, n_estimators: 100
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4714 | 0.4143 | 0.5286 | 0.4394 |
# learning_rate: 0.4780483941066377, n_estimators: 5
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4714 | 0.4429 | 0.5000 | 0.4559 |
# learning_rate: 0.4095494707808377, n_estimators: 50
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4500 | 0.4000 | 0.5000 | 0.4211 |
# learning_rate: 0.15343025958966724, n_estimators: 1000
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4857 | 0.4714 | 0.5000 | 0.4783 |
# learning_rate: 0.3357436305902197, n_estimators: 100
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4643 | 0.4286 | 0.5000 | 0.4444 |
# learning_rate: 0.3356853962580967, n_estimators: 1000
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4643 | 0.4286 | 0.5000 | 0.4444 |
# learning_rate: 0.37597891419258167, n_estimators: 200
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4714 | 0.4286 | 0.5143 | 0.4478 |
# learning_rate: 0.34955312558646845, n_estimators: 1000
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4643 | 0.4286 | 0.5000 | 0.4444 |
# learning_rate: 0.20388765740379058, n_estimators: 100
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4857 | 0.4571 | 0.5143 | 0.4706 |
# learning_rate: 0.5780412653101573, n_estimators: 50
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4786 | 0.4714 | 0.4857 | 0.4748 |
# learning_rate: 0.4038571976249521, n_estimators: 100
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4500 | 0.4000 | 0.5000 | 0.4211 |
# learning_rate: 0.5355407448038169, n_estimators: 500
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4786 | 0.4571 | 0.5000 | 0.4672 |
# learning_rate: 0.5551310666060872, n_estimators: 500
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4643 | 0.4286 | 0.5000 | 0.4444 |
# learning_rate: 0.4127526517633273, n_estimators: 200
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4500 | 0.4000 | 0.5000 | 0.4211 |
# learning_rate: 0.3952723131307144, n_estimators: 5
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4643 | 0.4286 | 0.5000 | 0.4444 |
# learning_rate: 0.2436551512046142, n_estimators: 1
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.2500 | 0.1857 | 0.3143 | 0.1985 |
# learning_rate: 0.21425634947176206, n_estimators: 1000
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.5000 | 0.4857 | 0.5143 | 0.4928 |
# learning_rate: 0.20396499341825722, n_estimators: 1
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.2500 | 0.1857 | 0.3143 | 0.1985 |
# learning_rate: 0.5993366905197292, n_estimators: 500
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4786 | 0.4714 | 0.4857 | 0.4748 |
# learning_rate: 0.23354384535500197, n_estimators: 500
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4786 | 0.4571 | 0.5000 | 0.4672 |
# learning_rate: 0.10995732665887406, n_estimators: 100
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4929 | 0.4571 | 0.5286 | 0.4741 |
# learning_rate: 0.4779064098303428, n_estimators: 5
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4714 | 0.4429 | 0.5000 | 0.4559 |
# learning_rate: 0.14059370793722906, n_estimators: 200
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4929 | 0.4714 | 0.5143 | 0.4818 |
# learning_rate: 0.2914933622774236, n_estimators: 50
#
# | Model Name |   Set   |Accuracy | Sensitivity | Specificity | F1 Score |
# |------------|----------|----------|-------------|-------------|----------|
# | Decision Tree | test | 0.4714 | 0.4429 | 0.5000 | 0.4559 |

# %%
feature_importances = model.feature_importances_
print("特征重要性：", feature_importances)

demographic_name = np.array([
    ['Age (years)', 'Sex', 'Ethnicity', 'Handedness', 'Education (years)', 
    'Current/highest education level —  Coded', 'Perceived social support', 
    'Past trauma', 'Current psychiatric comorbidities — Binary', 
    'Current psychiatric comorbidities — Coded', 'Family history of psychiatric illness']
])

for i,v in enumerate(feature_importances):
    print('Feature: %s, Score: %.5f, %0d' % (demographic_name[0][i],v,i))
# Out:
# 特征重要性： [0.00734201 0.         0.         0.29543024 0.         0.16029395
#  0.01750298 0.44857877 0.         0.07085204]
# Feature: Age (years), Score: 0.00734, 0
# Feature: Sex, Score: 0.00000, 1
# Feature: Ethnicity, Score: 0.00000, 2
# Feature: Handedness, Score: 0.29543, 3
# Feature: Education (years), Score: 0.00000, 4
# Feature: Current/highest education level —  Coded, Score: 0.16029, 5
# Feature: Perceived social support, Score: 0.01750, 6
# Feature: Past trauma, Score: 0.44858, 7
# Feature: Current psychiatric comorbidities — Binary, Score: 0.00000, 8
# Feature: Current psychiatric comorbidities — Coded, Score: 0.07085, 9

# %%
def kfold_get_metrics(result):
    folds_result = []
    for i in range(len(result)):
        x = get_metrics(result[i,1], result[i,0])
        folds_result.append(x)

    folds_result = np.array(folds_result)
    folds_result = np.mean(folds_result, axis=0)
    return folds_result
